# %%
#Exp_no:2

# %%
#Aim : Central Tendency of Measures Mean,Median Mode

# %%
#Name:Tanisha S Gour
#Roll no:71
#Sec:B
#Subject:ET1
#Date:31/7/2025

# %%
age=[22,21,20,22,20,23,24,23,25]

# %%
age
# Out:
# [22, 21, 20, 22, 20, 23, 24, 23, 25]

# %%
import statistics as st

# %%
a=st.mean(age)

# %%
a
# Out:
# 22.22222222222222

# %%
b=st.median(age)

# %%
b
# Out:
# 22

# %%
c=st.mode(age)

# %%
c
# Out:
# 22

# %% [markdown]
# # Performing_Central_Tendancy_Of_Measure_Using_Numpy

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,2,3,5,6])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 2, 3, 5, 6])

# %%
print(np.mean(x))
# Out:
# 3.7

# %%
print(np.median(x))
# Out:
# 3.5

# %% [markdown]
#  # Performing_Central_Tendancy_Of_Measure_Using_Scipy

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(2))

# %%
print(np.std(x))
# Out:
# 1.676305461424021

# %%
print(np.var(x))
# Out:
# 2.81
