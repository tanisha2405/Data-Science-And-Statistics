# %%
#Exp_no:3

# %%
#Aim: Creating the Dataframe

# %%
#Name:Tanisha S Gour
#Roll no:71
#Sec:B
#Subject:ET1
#Date:07/8/2025

# %% [markdown]
# # Creating Series

# %%
 import pandas as pd

# %%
Name=["Komal","Nandini","Avantika","Bhumi","Riddhi"]
Name
# Out:
# ['Komal', 'Nandini', 'Avantika', 'Bhumi', 'Riddhi']

# %%
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1       Komal
# 2     Nandini
# 3    Avantika
# 4       Bhumi
# 5      Riddhi
# dtype: object

# %% [markdown]
# # Creating Data Frame

# %%
 import pandas as pd

# %%
df=pd.DataFrame([[10,15,17,18],[12,14,15,17],[11,12,13,15],[12,13,14,16],[12,13,15,12]],
columns= ["CD","CAO","DBMS","DSS"])

# %%
df
# Out:
#    CD  CAO  DBMS  DSS
# 0  10   15    17   18
# 1  12   14    15   17
# 2  11   12    13   15
# 3  12   13    14   16
# 4  12   13    15   12

# %%
 df.shape
# Out:
# (5, 4)

# %%
df.size
# Out:
# 20

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record (row) to the data frame

# %%
df2=pd.DataFrame([[5,8,9,7]],
columns= ["CD","CAO","DBMS","DSS"])

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    CD  CAO  DBMS  DSS
# 0  10   15    17   18
# 1  12   14    15   17
# 2  11   12    13   15
# 3  12   13    14   16
# 4  12   13    15   12
# 5   5    8     9    7

# %% [markdown]
# # Adding Attribute (coloumn) in a data frame

# %%
df3["DM"]=[12,15,12,7,12,7]

# %%
df3
# Out:
#    CD  CAO  DBMS  DSS  DM
# 0  10   15    17   18  12
# 1  12   14    15   17  15
# 2  11   12    13   15  12
# 3  12   13    14   16   7
# 4  12   13    15   12  12
# 5   5    8     9    7   7

# %% [markdown]
# # Deleting Record from Data Frame

# %%
df4=df3.drop(1)

# %%
df4
# Out:
#    CD  CAO  DBMS  DSS  DM
# 0  10   15    17   18  12
# 2  11   12    13   15  12
# 3  12   13    14   16   7
# 4  12   13    15   12  12
# 5   5    8     9    7   7

# %% [markdown]
# # Deleting Attribute (Coloumns) from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  CAO  DBMS  DSS
# 0  10   15    17   18
# 1  12   14    15   17
# 2  11   12    13   15
# 3  12   13    14   16
# 4  12   13    15   12
# 5   5    8     9    7

# %%
print("Mean of DSS:", df5["DSS"].mean())
# Out:
# Mean of DSS: 14.166666666666666

# %%
print("Median of DSS:", df5["DSS"].median())
# Out:
# Median of DSS: 15.5

# %%
print("Mode of DSS:", df5["DSS"].mode())
# Out:
# Mode of DSS: 0     7
# 1    12
# 2    15
# 3    16
# 4    17
# 5    18
# Name: DSS, dtype: int64
